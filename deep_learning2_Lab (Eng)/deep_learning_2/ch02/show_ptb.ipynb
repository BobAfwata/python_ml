# %%
# Module for using Google Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
import sys
sys.path.append('..')
from dataset import ptb

# %%
corpus, word_to_id, id_to_word = ptb.load_data('train')

# %%
print('Corpus Size:', len(corpus))  # Print the size of the corpus
print('corpus[:30]:', corpus[:30])   # Print the first 30 elements of the corpus
print()
print('id_to_word[0]:', id_to_word[0])   # Print the word corresponding to id 0
print('id_to_word[1]:', id_to_word[1])   # Print the word corresponding to id 1
print('id_to_word[2]:', id_to_word[2])   # Print the word corresponding to id 2
print()
print("word_to_id['car']:", word_to_id['car'])     # Print the id corresponding to the word 'car'
print("word_to_id['happy']:", word_to_id['happy']) # Print the id corresponding to the word 'happy'
print("word_to_id['lexus']:", word_to_id['lexus']) # Print the id corresponding to the word 'lexus'
