# %%
# Module for using Google Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
import sys
sys.path.append('..')  # Set up to be able to import files from the parent directory
from dataset import spiral  # Import the spiral dataset module
import matplotlib.pyplot as plt  # Import matplotlib for plotting

# %%
# Install numpy version 1.23.0 for loading the spiral dataset
# After installation, restart the session and then execute the code
# !pip install numpy==1.23.0

# %%
# Load the data from the spiral dataset
x, t = spiral.load_data()

# Print the shape of the input data x
print('x', x.shape)  # (300, 2)

# Print the shape of the target data t
print('t', t.shape)  # (300, 3)

# %%
# Plot data points
N = 100
CLS_NUM = 3
markers = ['o', 'x', '^']

# Scatter plot for each class
for i in range(CLS_NUM):
    plt.scatter(x[i*N:(i+1)*N, 0], x[i*N:(i+1)*N, 1], s=40, marker=markers[i])

# Display the plot
plt.show()
